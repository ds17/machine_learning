# %% [markdown]
# ## Normalizing input

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import h5py

# %matplotlib inline

# %%
np.random.seed(3)

# %%
s = np.random.rand(2,40)

# %%
mean = np.mean(s, axis=1,keepdims=True)

# %%
ss =s - mean

# %%
var = np.var(s, axis=1,keepdims=True)
sss = ss / var

# %%
fig1, axes = plt.subplots(nrows=1, ncols=3, figsize=(18,6));
axes[0].scatter(s[0,:], s[1,:]);
axes[1].scatter(ss[0,:], ss[1,:]);
axes[2].scatter(sss[0,:], sss[1,:]);

# %%
def spines_edit(axes):
    for ax in axes:
        ax.spines['top'].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.spines["bottom"].set_position(('data',0))
        ax.spines["left"].set_position(('data',0))

# %%
spines_edit(axes)
fig1

# %%
nss = s - s.mean()

# %%
nsss = nss /(nss.var())

# %%
fig2, axes2= plt.subplots(nrows=1, ncols=3, figsize=(18,6))
axes2[0].scatter(s[0,:], s[1,:]);
axes2[1].scatter(nss[0,:], ss[1,:]);
axes2[2].scatter(nsss[0,:], sss[1,:]);
spines_edit(axes2)

# %%
s.mean(), ss.mean(), sss.mean()
# Out:
# (0.45044690395657022, 1.1102230246251566e-17, 2.2204460492503131e-16)

# %%
s.mean(), nss.mean(), nsss.mean()
# Out:
# (0.45044690395657022, -4.163336342344337e-17, -4.8849813083506892e-16)

# %%
s.var(), nss.var(), nsss.var()
# Out:
# (0.063975671702946407, 0.063975671702946407, 15.630941784296184)
