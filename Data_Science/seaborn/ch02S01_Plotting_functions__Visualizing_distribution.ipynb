# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#Visualizing-the-distribution-of-a-dataset" data-toc-modified-id="Visualizing-the-distribution-of-a-dataset-1">Visualizing the <code>distribution</code> of a dataset</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#1---Univariate-distribution" data-toc-modified-id="1---Univariate-distribution-1.1">1 - Univariate distribution</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#sns.distplot()" data-toc-modified-id="sns.distplot()-1.1.1"><a href="http://seaborn.pydata.org/generated/seaborn.distplot.html#seaborn.distplot" target="_blank"><code>sns.distplot()</code></a></a></span></li><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#sns.kdeplot()" data-toc-modified-id="sns.kdeplot()-1.1.2"><a href="http://seaborn.pydata.org/generated/seaborn.kdeplot.html#seaborn.kdeplot" target="_blank"><code>sns.kdeplot()</code></a></a></span></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#2---Bivariate-distributions" data-toc-modified-id="2---Bivariate-distributions-1.2">2 - Bivariate distributions</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#sns.jointplot()" data-toc-modified-id="sns.jointplot()-1.2.1"><a href="http://seaborn.pydata.org/generated/seaborn.jointplot.html#seaborn.jointplot" target="_blank"><code>sns.jointplot()</code></a></a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#plt.scatter()" data-toc-modified-id="plt.scatter()-1.2.1.1"><a href="http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter" target="_blank"><code>plt.scatter()</code></a></a></span></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#sns.rugplot()" data-toc-modified-id="sns.rugplot()-1.2.2"><code>sns.rugplot()</code></a></span></li><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#cmap" data-toc-modified-id="cmap-1.2.3"><code>cmap</code></a></span></li><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#sns.JiontGrid()" data-toc-modified-id="sns.JiontGrid()-1.2.4"><a href="http://seaborn.pydata.org/generated/seaborn.JointGrid.html#seaborn.JointGrid" target="_blank"><code>sns.JiontGrid()</code></a></a></span></li></ul></li><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#3---Multiple-pairwise-bivarite-dist" data-toc-modified-id="3---Multiple-pairwise-bivarite-dist-1.3">3 - Multiple pairwise bivarite dist</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#sns.pairplot()" data-toc-modified-id="sns.pairplot()-1.3.1"><a href="http://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn.pairplot" target="_blank"><code>sns.pairplot()</code></a></a></span></li><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#sns.PairGrid()" data-toc-modified-id="sns.PairGrid()-1.3.2"><a href="http://seaborn.pydata.org/generated/seaborn.PairGrid.html#seaborn.PairGrid" target="_blank"><code>sns.PairGrid()</code></a></a></span></li><li><span><a href="http://localhost:8888/notebooks/Machine%20Learning/seaborn/ch02S01_Plotting_functions__Visualizing_distribution.ipynb#plt.savefig(fname,-...)" data-toc-modified-id="plt.savefig(fname,-...)-1.3.3"><a href="http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.savefig" target="_blank"><code>plt.savefig(fname, ...)</code></a></a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Visualizing the `distribution` of a dataset

# %% [markdown]
# [Tutorial](http://seaborn.pydata.org/tutorial.html#tutorial)

# %% [markdown]
# ## 1 - Univariate distribution

# %%
# %matplotlib inline

# %%
import matplotlib as mpl

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats, integrate
# Out:
# D:\Python\Anaconda3\envs\tensorflow\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
sns.set(color_codes=True)

# %%
np.random.seed(sum(map(ord, "distributions")))

# %%
mean, cov =[0,1], [(1,.5), (0.5,1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

# %% [markdown]
# ### [`sns.distplot()`](http://seaborn.pydata.org/generated/seaborn.distplot.html#seaborn.distplot)
# ```python
# sns.distplot(a, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None)
# ```
# plot distribution
# - `hist`: 是否显示直方图
# - `kde`: 是否显示密度曲线
# - `rug`: 是否显示“小地毯”

# %%
x=np.random.normal(size=100)
sns.distplot(x,rug=True,);

# %%
sns.distplot(x, bins=30, rug=True, hist=False);

# %% [markdown]
# ### [`sns.kdeplot()`](http://seaborn.pydata.org/generated/seaborn.kdeplot.html#seaborn.kdeplot)
# `sns.kdeplot(data, data2=None, shade=False, vertical=False, kernel='gau', bw='scott', gridsize=100, cut=3, clip=None, legend=True, cumulative=False, shade_lowest=True, cbar=False, cbar_ax=None, cbar_kws=None, ax=None, **kwargs)`
# - `cut` : 曲线两端延伸长度，只影响曲线的位置和比例 ，不影响拟合的结果
# - `bw` : 估算概率密度时，直方图的 `bandwidth`

# %%
sns.kdeplot(x, label="guess")
sns.kdeplot(x, bw=.2, label="bw: 0.2",lw=3)
sns.kdeplot(x, bw=2, label="bw: 2");

# %%
plt.subplot(141)
sns.kdeplot(x, bw=2, label="cut: 0",cut=0);
plt.subplot(142)
sns.kdeplot(x, bw=2, label="bw: 6",cut=6);
plt.subplot(143)
sns.kdeplot(x, bw=2, cut=1 ,label="cut: 1");
plt.subplot(144)
sns.kdeplot(x, bw=2);
plt.tight_layout()

# %% [markdown]
# ## 2 - Bivariate distributions

# %% [markdown]
# ### [`sns.jointplot()`](http://seaborn.pydata.org/generated/seaborn.jointplot.html#seaborn.jointplot)
# `sns.jointplot(x, y, data=None, kind='scatter', stat_func=<function pearsonr>, color=None, size=6, ratio=5, space=0.2, dropna=True, xlim=None, ylim=None, joint_kws=None, marginal_kws=None, annot_kws=None, **kwargs)`
# - `kind` : scatter, kde, hex

# %%
plt.scatter(df["x"],df["y"]);

# %%
sns.jointplot(x="x", y="y", data=df,xlim=(-3,4));

# %%
with sns.axes_style("white"):
    sns.jointplot(x="x", y="y", data=df, kind="hex", color="k")

# %% [markdown]
# `jointplot()` returns the `JointGrid` object after plotting

# %% [markdown]
# #### [`plt.scatter()`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter)
# `plt.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, hold=None, data=None)`
# - [`matplotlib.markers`](http://matplotlib.org/api/markers_api.html#module-matplotlib.markers)

# %%
g = sns.JointGrid(df.x, df.y, ylim=(-1,4),size=5, space=0.1)
g = g.plot_joint(plt.scatter, c="g", s=30, linewidth=1, marker="+")
g = g.plot_marginals(sns.kdeplot, shade=True)
g.ax_joint.collections[0].set_alpha(0.5)
g.set_axis_labels("$X$", "$Y$");

# %% [markdown]
# ### `sns.rugplot()`

# %%
f, axes= plt.subplots(ncols=2,figsize=(16,5))
sns.kdeplot(data=df,ax=axes[0]);
sns.rugplot(df.x, ax=axes[0]);
sns.rugplot(df.y, vertical=True,ax=axes[0]);
sns.distplot(df.x,ax=axes[1]);

# %% [markdown]
# ### `cmap`

# %%
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df.x, df.y, cmap=cmap,shade=True, n_levels=60);

# %% [markdown]
# ### [`sns.JiontGrid()`](http://seaborn.pydata.org/generated/seaborn.JointGrid.html#seaborn.JointGrid)
# `sns.JointGrid(x, y, data=None, size=6, ratio=5, space=0.2, dropna=True, xlim=(0,5), ylim=(1,3))`
# - `ratio` : Ratio of joint axes size to marginal axes height.
# - `g.ax_marg_x` : AxesSubplot 对象，`matplotlib` 的子绘图区域
# - `g.ax_marg_y` : 同上

# %%
g = sns.JointGrid(x="x", y="y", data=df)
g.plot(plt.scatter, sns.kdeplot);

# %%
g = sns.JointGrid(x="x", y="y", data=df)
g = g.plot_joint(sns.regplot, color="g")
g = g.plot_marginals(sns.distplot, color="r")

# %%
g = sns.JointGrid(df.x, df.y, space=0.1, size=5)
_ = g.plot_joint(sns.regplot, color="g")
sns.kdeplot(df.x, shade=True, ax=g.ax_marg_x)
_ = g.ax_marg_y.hist(df.y, orientation="horizontal",color="r")

# %% [markdown]
# `sns.JointGrid(..., ration=2)`
#
# `sns.JointGrid(..., space=1, size=5, ration=2)`

# %%
g = sns.JointGrid(x="x", y="y", data=df, size=5, ratio=6, ylim=(-1.5,4))
g = g.plot_joint(plt.scatter, color="g", edgecolor="white")
g = g.plot_marginals(sns.kdeplot)
g = g.annotate(stats.pearsonr)

# %% [markdown]
# ## 3 - Multiple pairwise bivarite dist

# %% [markdown]
# ### [`sns.pairplot()`](http://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn.pairplot)
# ```python
# sns.pairplot(data, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='hist', markers=None, size=2.5, aspect=1, dropna=True, plot_kws=None, diag_kws=None, grid_kws=None)
# ```
# - `x_i, x_j` 两两绘图
# - `i=j` 时， `"dist"`
# - `i≠j` 时， `"scatter"` or `"reg"`
# - `kind` : `"scatter"` or `"reg"`

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris, markers="+", kind="reg");

# %%
sns.pairplot(df);

# %% [markdown]
# ### [`sns.PairGrid()`](http://seaborn.pydata.org/generated/seaborn.PairGrid.html#seaborn.PairGrid)
# ```python
# sns.PairGrid(data, hue=None, hue_order=None, palette=None, hue_kws=None, vars=None, x_vars=None, y_vars=None, diag_sharey=True, size=2.5, aspect=1, despine=True, dropna=True)
# ```
# - `g.map_diag(...)`
# - `g.map_offdiag(...)`

# %% [markdown]
# **`key words`**
# - legend: 图例
# - diagnal: 对角线

# %%
g = sns.PairGrid(iris, hue="species")

#绘制对角线区域：i=j
g.map_diag(plt.hist, histtype="step", linewidth=3)  

#绘制非对角线区域：i≠j
g.map_offdiag(plt.scatter);

g = g.add_legend();

# %%
list(iris.columns)
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
g = sns.PairGrid(iris, vars=['sepal_length','sepal_width'], hue="species")
g = g.map(plt.scatter)
g = g.add_legend();

# %%
g = sns.PairGrid(iris, hue="species",
                x_vars=['sepal_length', 'sepal_width'],
                y_vars=['petal_length', 'petal_width'])
_ = g.map(plt.scatter)
_ = g.add_legend();

# %%
g = sns.PairGrid(iris)

#upper triangle
_ = g.map_upper(plt.scatter)

#lower trianngle
_ = g.map_lower(sns.kdeplot)
_ = g.map_diag(sns.kdeplot, lw=3, legend=True);
# Out:
# D:\Python\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
iris[:1]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %% [markdown]
# Use different colors and markers for each categorical level

# %%
g = sns.PairGrid(iris, hue="species", palette="Set2",
                hue_kws={"marker":["o", "s", "D"]})
_ = g.map(plt.scatter, linewidth=1, edgecolor="w", s=40)
_ = g.add_legend()

# %% [markdown]
# ### [`plt.savefig(fname, ...)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.savefig)
# ```python
# plt.savefig(fname, dpi=None, facecolor='w', edgecolor='w',
#         orientation='portrait', papertype=None, format=None,
#         transparent=False, bbox_inches=None, pad_inches=0.1,
#         frameon=None)
# ```

# %%
g.savefig("results/ch02s01_parigrid_irsi", dpi=300)
